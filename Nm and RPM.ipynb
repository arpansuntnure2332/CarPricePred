# %%
import pandas as pd
import re

# %%
df = pd.read_csv("Car details v3.csv")

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
print(len(df.columns))
# Out:
# 13

# %%
df.dropna(inplace = True)

# %%
def N_M(value):
    value=value* 9.80665 
    return value

# %% [markdown]
# def N_M(value):
#     nm=value* 9.80665
#     return nm
#
#
# lst= strg.split("@")
# if len(lst)==1:
#     m=re.findall(r"[-+]?\d*\.\d+|\d+", strg)
#        # x = re.findall('[0-9]+', strg)
#         #print("m",m)
#     if len(m)==3:
#         df["NM"][i]=m[0]
#         df["RPM"][i]=int(m[2])-int(m[1])
#     else:
#             df["NM"][i]=m[0]
#             df["RPM"][i]=m[1]
#     else:
#         x=re.findall(r"[-+]?\d*\.\d+|\d+", strg)
#         #print("x", x)
#         if len(x)==2:
#             df["NM"][i]=x[0]
#             df["RPM"][i]=x[1]
#         elif len(x)==3:
#             df["NM"][i]=x[0]
#             df["RPM"][i]=int(x[2])-int(x[1])
# print(df.head(13))

# %%
df.count()
df["NM"]=""
df["RPM"]=""
for i in range(0,13):
    strg=df["torque"][i]
    valid=strg.find("kgm")
    
    
    if valid!=(-1):
        lst = strg.split("@")
        if len(lst)==1:
            m =re.findall(r"[-+]?\d*\.\d+|\d+", strg)
            if len(m)==3:
                df["NM"][i]=N_M(float(m[0]))
                df["RPM"][i]=int(m[2])-int(m[1])
            else:
                df["NM"][i]=N_M(m[0])
                df["RPM"][i]=m[1]
        else:
            x =re.findall(r"[-+]?\d*\.\d+|\d+", strg)
            if len(x)==3:
                df["NM"][i]=N_M(float(x[0]))
                df["RPM"][i]=int(x[2])-int(x[1])
            else:
                df["NM"][i]=N_M(m[0])
                df["RPM"][i]=m[1]
    else:
        if len(lst)==1:
            m =re.findall(r"[-+]?\d*\.\d+|\d+", strg)
            if len(m)==3:
                df["NM"][i]=m[0]
                df["RPM"][i]=int(m[2])-int(m[1])
            else:
                df["NM"][i]=m[0]
                df["RPM"][i]=m[1]
        else:
            x=re.findall(r"[-+]?\d*\.\d+|\d+", strg)
            if len(x)==3:
                df["NM"][i]=x[0]
                df["RPM"][i]=int(x[2])-int(x[1])
            else:
                df["NM"][i]=x[0]
                df["RPM"][i]=x[1]
        
print(df.head())
df
        #if (i % 2) == 0:
            #df["NM"]=lst[i]
        #else:
            #df["RPM"]=lst[i]
    #Nm=lst[0]
    #rpm=lst[2]
   # print(lst)
    #print(Nm)
    #leng=len(lst)
    #df["NM"]=lst[0]
    #df["RPM"]=lst[1]

#print(df.head(50))
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats       NM   RPM
# ...
